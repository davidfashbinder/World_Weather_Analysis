# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import g_key
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 585

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_condition = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Current Description": city_condition
                        })

#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jacksonville
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | bonavista
# Processing Record 5 of Set 1 | mana
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | pevek
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | gizo
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | saint-francois
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | tuatapere
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | fowa
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | port-gentil
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | lompoc
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | srednekolymsk
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | san cosme y damian
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | ketchikan
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | castro verde
# Processing Record 35 of Set 1 | vostok
# Processing Record 36 of Set 1 | taveta
# Processing Record 37 of Set 1 | lobanovo
# Processing Record 38 of Set 1 | okhotsk
# Processing Record 39 of Set 1 | ubinskoye
# Processing Record 40 of Set 1 | caravelas
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | palmer
# Processing Record 43 of Set 1 | tautira
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | alofi
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | aloleng
# Processing Record 49 of Set 1 | kanniyakumari
# Processing Record 50 of Set 1 | pozo colorado
# Processing Record 1 of Set 2 | ushtobe
# Processing Record 2 of Set 2 | methoni
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | narrabri
# Processing Record 5 of Set 2 | beni
# Processing Record 6 of Set 2 | lucapa
# Processing Record 7 of Set 2 | waipawa
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | angostura
# Processing Record 12 of Set 2 | hualmay
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | vung tau
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | san carlos
# Processing Record 18 of Set 2 | laguna
# Processing Record 19 of Set 2 | karla
# Processing Record 20 of Set 2 | maceio
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | la union
# Processing Record 23 of Set 2 | tiarei
# Processing Record 24 of Set 2 | daru
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | broome
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | qarchi gak
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | praia da vitoria
# Processing Record 33 of Set 2 | kahului
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | itoman
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | olafsvik
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | egvekinot
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | pias
# Processing Record 43 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 44 of Set 2 | cayenne
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 2 | ucluelet
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | komsomolskiy
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 2 of Set 3 | isangel
# Processing Record 3 of Set 3 | greenwood village
# Processing Record 4 of Set 3 | coquimbo
# Processing Record 5 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 3 | solnechnyy
# Processing Record 7 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 3 | basco
# Processing Record 9 of Set 3 | campo maior
# Processing Record 10 of Set 3 | samandag
# Processing Record 11 of Set 3 | teahupoo
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | mount isa
# Processing Record 14 of Set 3 | saint george
# Processing Record 15 of Set 3 | bam
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | alice springs
# Processing Record 18 of Set 3 | hovd
# Processing Record 19 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 3 | lincoln
# Processing Record 21 of Set 3 | san patricio
# Processing Record 22 of Set 3 | narsaq
# Processing Record 23 of Set 3 | tiznit
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | ayan
# Processing Record 26 of Set 3 | khorol
# Processing Record 27 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | agadir
# Processing Record 30 of Set 3 | vestmannaeyjar
# Processing Record 31 of Set 3 | boynton beach
# Processing Record 32 of Set 3 | longyearbyen
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | havre-saint-pierre
# Processing Record 35 of Set 3 | katsuura
# Processing Record 36 of Set 3 | shingu
# Processing Record 37 of Set 3 | syamzha
# Processing Record 38 of Set 3 | lewistown
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | atuona
# Processing Record 42 of Set 3 | severobaykalsk
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | san cristobal
# Processing Record 46 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | beyneu
# Processing Record 49 of Set 3 | slave lake
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 4 | manaure
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | ahipara
# Processing Record 7 of Set 4 | barra do garcas
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 4 | pacific grove
# Processing Record 11 of Set 4 | podgornoye
# Processing Record 12 of Set 4 | kupang
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | vardo
# Processing Record 15 of Set 4 | bandarbeyla
# Processing Record 16 of Set 4 | abu dhabi
# Processing Record 17 of Set 4 | jacareacanga
# Processing Record 18 of Set 4 | balabac
# Processing Record 19 of Set 4 | asau
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | labuhan
# Processing Record 22 of Set 4 | yar-sale
# Processing Record 23 of Set 4 | graaff-reinet
# Processing Record 24 of Set 4 | koungou
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | vitre
# Processing Record 27 of Set 4 | provideniya
# Processing Record 28 of Set 4 | jackson
# Processing Record 29 of Set 4 | opuwo
# Processing Record 30 of Set 4 | sorland
# Processing Record 31 of Set 4 | siddapur
# Processing Record 32 of Set 4 | norman wells
# Processing Record 33 of Set 4 | lockhart
# Processing Record 34 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 4 | dehui
# Processing Record 36 of Set 4 | guerrero negro
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 4 | lavrentiya
# Processing Record 40 of Set 4 | hami
# Processing Record 41 of Set 4 | guilin
# Processing Record 42 of Set 4 | acapulco
# Processing Record 43 of Set 4 | arcachon
# Processing Record 44 of Set 4 | faanui
# Processing Record 45 of Set 4 | vao
# Processing Record 46 of Set 4 | katobu
# Processing Record 47 of Set 4 | qaanaaq
# Processing Record 48 of Set 4 | rotifunk
# Processing Record 49 of Set 4 | bathsheba
# Processing Record 50 of Set 4 | tabukiniberu
# City not found. Skipping...
# Processing Record 1 of Set 5 | karpogory
# Processing Record 2 of Set 5 | pimentel
# Processing Record 3 of Set 5 | maymanak
# City not found. Skipping...
# Processing Record 4 of Set 5 | port blair
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | coos bay
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | gazanjyk
# Processing Record 9 of Set 5 | kiruna
# Processing Record 10 of Set 5 | grindavik
# Processing Record 11 of Set 5 | illapel
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | salinopolis
# Processing Record 15 of Set 5 | clyde river
# Processing Record 16 of Set 5 | kurmanayevka
# Processing Record 17 of Set 5 | san antonio
# Processing Record 18 of Set 5 | sawtell
# Processing Record 19 of Set 5 | newport
# Processing Record 20 of Set 5 | barcelos
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | seoul
# Processing Record 23 of Set 5 | susanville
# Processing Record 24 of Set 5 | quelimane
# Processing Record 25 of Set 5 | raymondville
# Processing Record 26 of Set 5 | hargeysa
# Processing Record 27 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 5 | xiongzhou
# Processing Record 29 of Set 5 | nantucket
# Processing Record 30 of Set 5 | bayan
# Processing Record 31 of Set 5 | hervey bay
# Processing Record 32 of Set 5 | rotenburg
# Processing Record 33 of Set 5 | sumenep
# Processing Record 34 of Set 5 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 35 of Set 5 | gunjur
# Processing Record 36 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 5 | buchanan
# Processing Record 38 of Set 5 | petrolandia
# City not found. Skipping...
# Processing Record 39 of Set 5 | ixtlan
# Processing Record 40 of Set 5 | mizdah
# Processing Record 41 of Set 5 | kieta
# Processing Record 42 of Set 5 | vanimo
# Processing Record 43 of Set 5 | kikwit
# Processing Record 44 of Set 5 | henties bay
# Processing Record 45 of Set 5 | leningradskiy
# Processing Record 46 of Set 5 | san carlos de bariloche
# Processing Record 47 of Set 5 | mahon
# Processing Record 48 of Set 5 | cao bang
# Processing Record 49 of Set 5 | kruisfontein
# Processing Record 50 of Set 5 | sabha
# Processing Record 1 of Set 6 | wilmington
# Processing Record 2 of Set 6 | thinadhoo
# Processing Record 3 of Set 6 | northam
# Processing Record 4 of Set 6 | garowe
# Processing Record 5 of Set 6 | sioux lookout
# Processing Record 6 of Set 6 | rong kwang
# Processing Record 7 of Set 6 | pavlysh
# Processing Record 8 of Set 6 | zyryanka
# Processing Record 9 of Set 6 | yarada
# Processing Record 10 of Set 6 | aquin
# Processing Record 11 of Set 6 | denia
# Processing Record 12 of Set 6 | kenai
# Processing Record 13 of Set 6 | bayshore gardens
# Processing Record 14 of Set 6 | olot
# Processing Record 15 of Set 6 | tandil
# Processing Record 16 of Set 6 | cherskiy
# Processing Record 17 of Set 6 | mogadishu
# Processing Record 18 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | sistranda
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | farmington
# Processing Record 24 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 6 | portland
# Processing Record 26 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 6 | faya
# Processing Record 28 of Set 6 | sitangkai
# Processing Record 29 of Set 6 | tual
# Processing Record 30 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 6 | atar
# Processing Record 32 of Set 6 | taltal
# Processing Record 33 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | porto novo
# Processing Record 36 of Set 6 | cabo san lucas
# Processing Record 37 of Set 6 | muros
# Processing Record 38 of Set 6 | bako
# Processing Record 39 of Set 6 | west bay
# Processing Record 40 of Set 6 | semey
# Processing Record 41 of Set 6 | smithers
# Processing Record 42 of Set 6 | puerto rondon
# Processing Record 43 of Set 6 | wellington
# Processing Record 44 of Set 6 | beberibe
# Processing Record 45 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 6 | okakarara
# Processing Record 47 of Set 6 | lebu
# Processing Record 48 of Set 6 | carupano
# Processing Record 49 of Set 6 | paamiut
# Processing Record 50 of Set 6 | tigil
# Processing Record 1 of Set 7 | yaan
# Processing Record 2 of Set 7 | coahuayana
# Processing Record 3 of Set 7 | kapit
# Processing Record 4 of Set 7 | novikovo
# Processing Record 5 of Set 7 | asfi
# Processing Record 6 of Set 7 | diamantino
# Processing Record 7 of Set 7 | milingimbi
# City not found. Skipping...
# Processing Record 8 of Set 7 | lagoa
# Processing Record 9 of Set 7 | benguela
# Processing Record 10 of Set 7 | auki
# Processing Record 11 of Set 7 | sambava
# Processing Record 12 of Set 7 | tilichiki
# Processing Record 13 of Set 7 | leh
# Processing Record 14 of Set 7 | luwuk
# Processing Record 15 of Set 7 | gubkinskiy
# Processing Record 16 of Set 7 | honjo
# Processing Record 17 of Set 7 | nhulunbuy
# Processing Record 18 of Set 7 | elko
# Processing Record 19 of Set 7 | sabang
# Processing Record 20 of Set 7 | sztum
# Processing Record 21 of Set 7 | shache
# Processing Record 22 of Set 7 | ayagoz
# Processing Record 23 of Set 7 | east london
# Processing Record 24 of Set 7 | taoudenni
# Processing Record 25 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 7 | mayahi
# Processing Record 27 of Set 7 | filingue
# Processing Record 28 of Set 7 | san joaquin
# Processing Record 29 of Set 7 | aktau
# Processing Record 30 of Set 7 | bambous virieux
# Processing Record 31 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 32 of Set 7 | sitka
# Processing Record 33 of Set 7 | codrington
# Processing Record 34 of Set 7 | mandan
# Processing Record 35 of Set 7 | vikhorevka
# Processing Record 36 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 37 of Set 7 | vierzon
# Processing Record 38 of Set 7 | westport
# Processing Record 39 of Set 7 | byron bay
# Processing Record 40 of Set 7 | adelaide
# Processing Record 41 of Set 7 | bardiyah
# Processing Record 42 of Set 7 | concarneau
# Processing Record 43 of Set 7 | mar del plata
# Processing Record 44 of Set 7 | mendi
# Processing Record 45 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 7 | villa bruzual
# Processing Record 47 of Set 7 | haines junction
# Processing Record 48 of Set 7 | niort
# Processing Record 49 of Set 7 | goedereede
# Processing Record 50 of Set 7 | north platte
# Processing Record 1 of Set 8 | tasiilaq
# Processing Record 2 of Set 8 | kalawit
# Processing Record 3 of Set 8 | terrak
# Processing Record 4 of Set 8 | unguia
# Processing Record 5 of Set 8 | ugoofaaru
# Processing Record 6 of Set 8 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 7 of Set 8 | kudahuvadhoo
# Processing Record 8 of Set 8 | dalvik
# Processing Record 9 of Set 8 | sakaraha
# Processing Record 10 of Set 8 | forst
# Processing Record 11 of Set 8 | erenhot
# Processing Record 12 of Set 8 | tiksi
# Processing Record 13 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 8 | butte
# Processing Record 15 of Set 8 | auburn
# Processing Record 16 of Set 8 | talaya
# Processing Record 17 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 8 | kautokeino
# Processing Record 19 of Set 8 | rudnogorsk
# Processing Record 20 of Set 8 | noumea
# Processing Record 21 of Set 8 | manbij
# Processing Record 22 of Set 8 | derzhavinsk
# Processing Record 23 of Set 8 | bukama
# Processing Record 24 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 8 | smolenka
# Processing Record 26 of Set 8 | saint-louis
# Processing Record 27 of Set 8 | gornopravdinsk
# Processing Record 28 of Set 8 | shelburne
# Processing Record 29 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 8 | vega de alatorre
# Processing Record 31 of Set 8 | berbera
# Processing Record 32 of Set 8 | hobyo
# Processing Record 33 of Set 8 | mitsamiouli
# Processing Record 34 of Set 8 | devonport
# Processing Record 35 of Set 8 | sept-iles
# Processing Record 36 of Set 8 | kloulklubed
# Processing Record 37 of Set 8 | carutapera
# Processing Record 38 of Set 8 | shambu
# Processing Record 39 of Set 8 | filadelfia
# Processing Record 40 of Set 8 | hella
# Processing Record 41 of Set 8 | tres arroyos
# Processing Record 42 of Set 8 | moindou
# Processing Record 43 of Set 8 | surt
# Processing Record 44 of Set 8 | colquechaca
# Processing Record 45 of Set 8 | nioro
# Processing Record 46 of Set 8 | jeremie
# Processing Record 47 of Set 8 | bereda
# Processing Record 48 of Set 8 | prainha
# Processing Record 49 of Set 8 | srandakan
# Processing Record 50 of Set 8 | berdigestyakh
# Processing Record 1 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 9 | oktyabrskiy
# Processing Record 3 of Set 9 | kungurtug
# Processing Record 4 of Set 9 | makakilo city
# Processing Record 5 of Set 9 | grand gaube
# Processing Record 6 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 9 | kawalu
# Processing Record 8 of Set 9 | diego de almagro
# Processing Record 9 of Set 9 | husavik
# Processing Record 10 of Set 9 | vuktyl
# Processing Record 11 of Set 9 | hirara
# Processing Record 12 of Set 9 | nizhniy kuranakh
# Processing Record 13 of Set 9 | havelock
# Processing Record 14 of Set 9 | tiruchchendur
# Processing Record 15 of Set 9 | gorkovskoye
# City not found. Skipping...
# Processing Record 16 of Set 9 | meulaboh
# Processing Record 17 of Set 9 | suclayin
# Processing Record 18 of Set 9 | hay river
# Processing Record 19 of Set 9 | kelowna
# Processing Record 20 of Set 9 | payo
# Processing Record 21 of Set 9 | celendin
# Processing Record 22 of Set 9 | barranca
# Processing Record 23 of Set 9 | manuk mangkaw
# Processing Record 24 of Set 9 | aksarka
# Processing Record 25 of Set 9 | mo i rana
# Processing Record 26 of Set 9 | asyut
# Processing Record 27 of Set 9 | padang
# Processing Record 28 of Set 9 | boquira
# Processing Record 29 of Set 9 | talnakh
# Processing Record 30 of Set 9 | trairi
# Processing Record 31 of Set 9 | halifax
# Processing Record 32 of Set 9 | matara
# Processing Record 33 of Set 9 | finnsnes
# Processing Record 34 of Set 9 | honningsvag
# Processing Record 35 of Set 9 | chupaca
# Processing Record 36 of Set 9 | oranjemund
# Processing Record 37 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 38 of Set 9 | souillac
# Processing Record 39 of Set 9 | hope
# Processing Record 40 of Set 9 | port hawkesbury
# Processing Record 41 of Set 9 | yerbogachen
# Processing Record 42 of Set 9 | geraldton
# Processing Record 43 of Set 9 | misratah
# Processing Record 44 of Set 9 | puerto colombia
# Processing Record 45 of Set 9 | chon buri
# Processing Record 46 of Set 9 | ajmer
# Processing Record 47 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 9 | ilula
# Processing Record 49 of Set 9 | araouane
# Processing Record 50 of Set 9 | kibre mengist
# Processing Record 1 of Set 10 | victoria
# Processing Record 2 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 10 | eureka
# Processing Record 4 of Set 10 | fare
# Processing Record 5 of Set 10 | krasnyy chikoy
# Processing Record 6 of Set 10 | belaya gora
# Processing Record 7 of Set 10 | severo-kurilsk
# Processing Record 8 of Set 10 | toccoa
# Processing Record 9 of Set 10 | maridi
# Processing Record 10 of Set 10 | svetlogorsk
# Processing Record 11 of Set 10 | villazon
# Processing Record 12 of Set 10 | waingapu
# Processing Record 13 of Set 10 | puerto escondido
# Processing Record 14 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 10 | don benito
# Processing Record 16 of Set 10 | yenagoa
# Processing Record 17 of Set 10 | touros
# Processing Record 18 of Set 10 | kiunga
# Processing Record 19 of Set 10 | sur
# Processing Record 20 of Set 10 | veraval
# Processing Record 21 of Set 10 | hammerfest
# Processing Record 22 of Set 10 | gualeguaychu
# Processing Record 23 of Set 10 | russell
# Processing Record 24 of Set 10 | bilibino
# Processing Record 25 of Set 10 | calamar
# Processing Record 26 of Set 10 | nocupetaro
# Processing Record 27 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 28 of Set 10 | saint-paul
# Processing Record 29 of Set 10 | san rafael
# Processing Record 30 of Set 10 | avera
# Processing Record 31 of Set 10 | fiumicino
# Processing Record 32 of Set 10 | meghri
# Processing Record 33 of Set 10 | umm jarr
# City not found. Skipping...
# Processing Record 34 of Set 10 | kichera
# Processing Record 35 of Set 10 | adeje
# Processing Record 36 of Set 10 | lubao
# Processing Record 37 of Set 10 | krasnoselkup
# Processing Record 38 of Set 10 | katangli
# Processing Record 39 of Set 10 | santa cruz
# Processing Record 40 of Set 10 | maniitsoq
# Processing Record 41 of Set 10 | nordhorn
# Processing Record 42 of Set 10 | mayumba
# Processing Record 43 of Set 10 | fort nelson
# Processing Record 44 of Set 10 | balkanabat
# Processing Record 45 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 46 of Set 10 | hambantota
# Processing Record 47 of Set 10 | salalah
# Processing Record 48 of Set 10 | okoneshnikovo
# Processing Record 49 of Set 10 | akyab
# Processing Record 50 of Set 10 | cockburn town
# Processing Record 1 of Set 11 | bakel
# Processing Record 2 of Set 11 | puerto del rosario
# Processing Record 3 of Set 11 | chiang klang
# Processing Record 4 of Set 11 | itarema
# Processing Record 5 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 11 | ostrovnoy
# Processing Record 7 of Set 11 | ovre ardal
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 11 | valley city
# Processing Record 11 of Set 11 | natal
# Processing Record 12 of Set 11 | nisia floresta
# Processing Record 13 of Set 11 | lorengau
# Processing Record 14 of Set 11 | burnie
# Processing Record 15 of Set 11 | klaksvik
# Processing Record 16 of Set 11 | zoniana
# Processing Record 17 of Set 11 | novosil
# Processing Record 18 of Set 11 | aguimes
# Processing Record 19 of Set 11 | luganville
# Processing Record 20 of Set 11 | midland
# Processing Record 21 of Set 11 | grenville
# Processing Record 22 of Set 11 | flinders
# Processing Record 23 of Set 11 | grand forks
# Processing Record 24 of Set 11 | keetmanshoop
# Processing Record 25 of Set 11 | lubango
# Processing Record 26 of Set 11 | berlevag
# Processing Record 27 of Set 11 | saquarema
# Processing Record 28 of Set 11 | santa maria
# Processing Record 29 of Set 11 | kavaratti
# Processing Record 30 of Set 11 | boa vista
# Processing Record 31 of Set 11 | dalby
# Processing Record 32 of Set 11 | taguatinga
# Processing Record 33 of Set 11 | zhangye
# Processing Record 34 of Set 11 | manaus
# Processing Record 35 of Set 11 | roald
# Processing Record 36 of Set 11 | gat
# Processing Record 37 of Set 11 | constitucion
# Processing Record 38 of Set 11 | aswan
# Processing Record 39 of Set 11 | verkhnevilyuysk
# Processing Record 40 of Set 11 | porto walter
# Processing Record 41 of Set 11 | evensk
# Processing Record 42 of Set 11 | kununurra
# Processing Record 43 of Set 11 | canico
# Processing Record 44 of Set 11 | chabahar
# Processing Record 45 of Set 11 | awbari
# Processing Record 46 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 11 | deputatskiy
# Processing Record 48 of Set 11 | nicoya
# Processing Record 49 of Set 11 | chumikan
# Processing Record 50 of Set 11 | mayskiy
# Processing Record 1 of Set 12 | paris
# Processing Record 2 of Set 12 | sao joao da barra
# Processing Record 3 of Set 12 | hofn
# Processing Record 4 of Set 12 | shimoda
# Processing Record 5 of Set 12 | takestan
# Processing Record 6 of Set 12 | sao joao da ponte
# Processing Record 7 of Set 12 | gazojak
# Processing Record 8 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 9 of Set 12 | mastic beach
# Processing Record 10 of Set 12 | troitskiy
# Processing Record 11 of Set 12 | chapais
# Processing Record 12 of Set 12 | rastolita
# Processing Record 13 of Set 12 | kajiado
# Processing Record 14 of Set 12 | goya
# Processing Record 15 of Set 12 | kjollefjord
# Processing Record 16 of Set 12 | novyy urgal
# Processing Record 17 of Set 12 | san policarpo
# Processing Record 18 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 12 | seymchan
# Processing Record 20 of Set 12 | ossora
# Processing Record 21 of Set 12 | bondo
# Processing Record 22 of Set 12 | pacasmayo
# Processing Record 23 of Set 12 | fukue
# Processing Record 24 of Set 12 | la palma
# Processing Record 25 of Set 12 | te anau
# Processing Record 26 of Set 12 | iracoubo
# Processing Record 27 of Set 12 | baherden
# Processing Record 28 of Set 12 | canitas
# City not found. Skipping...
# Processing Record 29 of Set 12 | shubarshi
# Processing Record 30 of Set 12 | kailua
# Processing Record 31 of Set 12 | tessalit
# Processing Record 32 of Set 12 | kihei
# Processing Record 33 of Set 12 | port lincoln
# Processing Record 34 of Set 12 | leshukonskoye
# Processing Record 35 of Set 12 | marevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jacksonville      US  30.33  -81.66     63.00        58           1
# 1          Ushuaia      AR -54.80  -68.30     50.00        61          75
# 2  Arraial Do Cabo      BR -22.97  -42.03     78.80        83          75
# 3        Bonavista      CA  48.65  -53.11     36.00        58          48
# 4             Mana      GF   5.66  -53.78     87.55        65          65
# 5        Busselton      AU -33.65  115.33     68.00        46          16
# 6            Pevek      RU  69.70  170.31     23.13        92          77
# 7            Vaini      TO -21.20 -175.20     71.60        78          75
# 8       Chokurdakh      RU  70.63  147.92      3.76        94         100
# 9       Bredasdorp      ZA -34.53   20.04     66.20        39           0
#
#    Wind Speed Current Description
# 0       11.41           clear sky
# 1       29.97       broken clouds
# 2       11.41       broken clouds
# 3       17.00    scattered clouds
# 4       13.85       broken clouds
# 5        2.62          few clouds
# 6        8.95       broken clouds
# 7        8.05       broken clouds
# 8        6.22     overcast clouds
# 9       11.41           clear sky

# %%
#Create the output file CSV
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
#Expoert the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
